# %% [markdown]
# <a href="https://colab.research.google.com/github/saleet-developer/Medical-RAG-Chatbot/blob/main/notebooks/colab/02-embedding-generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
