# %% [markdown]
# <a href="https://colab.research.google.com/github/saleet-developer/Medical-RAG-Chatbot/blob/main/notebooks/colab/01-data-processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
project_path = '/content/drive/MyDrive/Medical-RAG-Project'
os.listdir(project_path)
# Out:
# ['raw data',
#  'processed data',
#  'models',
#  'checkpoints',
#  'outputs',
#  'Untitled0.ipynb']
